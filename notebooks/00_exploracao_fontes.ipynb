# %% [markdown]
# # 00 — Exploração das fontes (Alfabetização)
#
# Inventário local das entidades. Em produção, consultar Base dos Dados / BigQuery.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path('..').resolve()
SAMPLE = ROOT / 'data' / 'sample'

if not (SAMPLE / 'manifest.json').exists():
    import sys
    sys.path.insert(0, str(ROOT))
    from pipelines.batch.generate_sample_data import build_samples
    build_samples()

for csv in sorted(SAMPLE.glob('*.csv')):
    df = pd.read_csv(csv)
    print(f"\n=== {csv.name} | shape={df.shape} ===")
    display(df.head(3))
    print('nulls:', df.isna().sum().to_dict())
